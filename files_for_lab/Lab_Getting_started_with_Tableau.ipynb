# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.Load the dataset into a notebook.

# %%
data= pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [markdown]
# ### 2.Create a barplot of the number of customers per Gender.

# %%
#first we should see how many customers we have for each gender

gender_counts = data['Gender'].value_counts()
gender_counts
# Out:
# F    4658
# M    4476
# Name: Gender, dtype: int64

# %%
plt.bar(gender_counts.index, gender_counts.values)

plt.xlabel('Gender')
plt.ylabel('Number of Customers')
plt.title('Number of Customers per Gender')


plt.show()

# %%
#another method:

import seaborn as sns

sns.countplot(x='Gender', data=data)

plt.title('Number of Customers per Gender')
plt.show()

# %% [markdown]
# ### 3. Create a barplot of the number of customers per EmploymentStatus and Gender.

# %%
gender_employment_counts = data.groupby(['EmploymentStatus', 'Gender']).size().unstack()

gender_employment_counts.plot(kind='bar', stacked=True)

plt.xlabel('Employment Status')
plt.ylabel('Number of Customers')
plt.title('Number of Customers per Employment Status and Gender')


plt.show()

# %%
#another method:

sns.countplot('EmploymentStatus', hue='Gender', data=data)
plt.title('Number of Customers per Employment Status and Gender')
plt.show()
# Out:
# /Users/hamidehaghaei/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### If we don't want stacked bars:

# %%
gender_employment_counts = data.groupby(['EmploymentStatus', 'Gender']).size().unstack()


gender_employment_counts.plot(kind='bar')

plt.xlabel('Employment Status')
plt.ylabel('Number of Customers')
plt.title('Number of Customers per Employment Status and Gender')

plt.legend(['Male', 'Female'])


plt.show()

# %% [markdown]
# ### 4.Identify Measurements and Dimensions. Are they the same as the ones in your Pandas dataframe? Modify accordingly.

# %% [markdown]
# In question 2 dimension is "gender" and measure is count of employees and in question 3 the dimensions are "gender" and "emplyment status" and the measure are the numbe of customers considering gender and "emplyment status".

# %% [markdown]
# ![easy-peasy-lemon-squeezy.gif](attachment:easy-peasy-lemon-squeezy.gif)
